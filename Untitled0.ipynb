# %%
c=0
for x in range(0, n):
  a=int(input("enter a number"))
  c+=a
  print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3157582588.py in <cell line: 0>()
#       1 c=0
# ----> 2 for x in range(0,n):
#       3   a=int(input("enter a number"))
#       4   c+=a
#       5   print(c)
#
# NameError: name 'n' is not defined
